# %%
import numpy as np
import pandas as pd 
import matplotlib as plt
import seaborn as sns
import plotly.express as px

# %%
excel_file = 'G:\DEPI(Data Analytics)\Final_Project\proj.xlsx'
sheets = pd.read_excel(excel_file, sheet_name=None)
print(sheets.keys())
# Out:
# dict_keys(['Categories', 'Employees', 'OrdersDetails', 'Customers', 'Products', 'Sales', 'Suppliers'])

# %%
categories =  sheets['Categories']
Employees = sheets['Employees']
OrdersDetails = sheets['OrdersDetails']
Sales = sheets['Sales']
Suppliers = sheets['Suppliers']
Products = sheets['Products']
Customers = sheets['Customers']

# %%
categories
# Out:
#    CategoryID    CategoryName  \
# 0         NaN             NaN
# 1         NaN             NaN
# 2         1.0       Beverages
# 3         2.0      Condiments
# 4         3.0     Confections
# 5         4.0  Dairy Products
# 6         5.0  Grains/Cereals
# 7         6.0    Meat/Poultry
# 8         7.0         Produce
# 9         8.0         Seafood
#
#                                          Description  Picture
# 0                                                NaN      NaN
# 1                                                NaN      NaN
# 2        Soft drinks, coffees, teas, beers, and ales      NaN
# 3  Sweet and savory sauces, relishes, spreads, an...      NaN
# 4                Desserts, candies, and sweet breads      NaN
# 5                                            Cheeses      NaN
# 6                Breads, crackers, pasta, and cereal      NaN
# 7                                     Prepared meats      NaN
# 8                          Dried fruit and bean curd      NaN
# ...

# %%
categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CategoryID    8 non-null      float64
#  1   CategoryName  8 non-null      object
#  2   Description   8 non-null      object
#  3   Picture       0 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 448.0+ bytes

# %%
categories.isna().sum()
# Out:
# CategoryID       2
# CategoryName     2
# Description      2
# Picture         10
# dtype: int64

# %%
categories.dropna(subset=['CategoryID', 'CategoryName', 'Description'], axis=0, inplace=True)

# %%
categories.isna().sum()
# Out:
# CategoryID      0
# CategoryName    0
# Description     0
# Picture         8
# dtype: int64

# %%
categories.drop(columns=['Picture'], inplace=True)

# %%
categories['CategoryID'] = categories['CategoryID'].astype('int64')

# %%
categories
# Out:
#    CategoryID    CategoryName  \
# 2           1       Beverages
# 3           2      Condiments
# 4           3     Confections
# 5           4  Dairy Products
# 6           5  Grains/Cereals
# 7           6    Meat/Poultry
# 8           7         Produce
# 9           8         Seafood
#
#                                          Description
# 2        Soft drinks, coffees, teas, beers, and ales
# 3  Sweet and savory sauces, relishes, spreads, an...
# 4                Desserts, candies, and sweet breads
# 5                                            Cheeses
# 6                Breads, crackers, pasta, and cereal
# 7                                     Prepared meats
# 8                          Dried fruit and bean curd
# 9                                   Seaweed and fish

# %%
Employees
# Out:
#    EmployeeID   LastName FirstName                     Title TitleOfCourtesy  \
# 0         1.0        NaN     Nancy      Sales Representative             Ms.
# 1         NaN        NaN       NaN                       NaN             NaN
# 2         2.0     Fuller    Andrew     Vice President, Sales             Dr.
# 3         3.0  Leverling     Janet                       NaN             NaN
# 4         4.0    Peacock  Margaret      Sales Representative            Mrs.
# 5         5.0   Buchanan    Steven             Sales Manager             Mr.
# 6         6.0     Suyama   Michael      Sales Representative             Mr.
# 7         7.0       King    Robert      Sales Representative             Mr.
# 8         8.0   Callahan     Laura  Inside Sales Coordinator             Ms.
# 9         9.0  Dodsworth      Anne      Sales Representative             Ms.
#
#    BirthDate   HireDate                                Address      City  \
# ...

# %%
Employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   EmployeeID       9 non-null      float64
#  1   LastName         8 non-null      object
#  2   FirstName        9 non-null      object
#  3   Title            8 non-null      object
#  4   TitleOfCourtesy  8 non-null      object
#  5   BirthDate        9 non-null      datetime64[ns]
#  6   HireDate         9 non-null      datetime64[ns]
#  7   Address          9 non-null      object
#  8   City             9 non-null      object
#  9   Region           5 non-null      object
#  10  PostalCode       9 non-null      object
#  11  Country          9 non-null      object
#  12  HomePhone        9 non-null      object
#  13  Extension        9 non-null      float64
#  14  Photo            9 non-null      object
#  15  Notes            9 non-null      object
# ...

# %%
Employees.isna().sum()
# Out:
# EmployeeID         1
# LastName           2
# FirstName          1
# Title              2
# TitleOfCourtesy    2
# BirthDate          1
# HireDate           1
# Address            1
# City               1
# Region             5
# PostalCode         1
# Country            1
# HomePhone          1
# Extension          1
# Photo              1
# Notes              1
# ReportsTo          2
# dtype: int64

# %%
Employees.drop(columns=['Photo','Region'], inplace=True)

# %%
Employees['LastName'].fillna('-', inplace=True)

# %%
Employees['Full Name'] = Employees['FirstName'] + ' ' + Employees['LastName']

# %%
Employees.isna().sum()
# Out:
# EmployeeID         1
# LastName           0
# FirstName          1
# Title              2
# TitleOfCourtesy    2
# BirthDate          1
# HireDate           1
# Address            1
# City               1
# PostalCode         1
# Country            1
# HomePhone          1
# Extension          1
# Notes              1
# ReportsTo          2
# Full Name          1
# dtype: int64

# %%
Employees['Title'].fillna(Employees['Title'].mode()[0], inplace=True)

# %%
Employees
# Out:
#    EmployeeID   LastName FirstName                     Title TitleOfCourtesy  \
# 0         1.0          -     Nancy      Sales Representative             Ms.
# 1         NaN          -       NaN      Sales Representative             NaN
# 2         2.0     Fuller    Andrew     Vice President, Sales             Dr.
# 3         3.0  Leverling     Janet      Sales Representative             NaN
# 4         4.0    Peacock  Margaret      Sales Representative            Mrs.
# 5         5.0   Buchanan    Steven             Sales Manager             Mr.
# 6         6.0     Suyama   Michael      Sales Representative             Mr.
# 7         7.0       King    Robert      Sales Representative             Mr.
# 8         8.0   Callahan     Laura  Inside Sales Coordinator             Ms.
# 9         9.0  Dodsworth      Anne      Sales Representative             Ms.
#
#    BirthDate   HireDate                                Address      City  \
# ...

# %%
Employees['TitleOfCourtesy'].fillna('Ms.', inplace=True)

# %%
Employees
# Out:
#    EmployeeID   LastName FirstName                     Title TitleOfCourtesy  \
# 0         1.0          -     Nancy      Sales Representative             Ms.
# 1         NaN          -       NaN      Sales Representative             Ms.
# 2         2.0     Fuller    Andrew     Vice President, Sales             Dr.
# 3         3.0  Leverling     Janet      Sales Representative             Ms.
# 4         4.0    Peacock  Margaret      Sales Representative            Mrs.
# 5         5.0   Buchanan    Steven             Sales Manager             Mr.
# 6         6.0     Suyama   Michael      Sales Representative             Mr.
# 7         7.0       King    Robert      Sales Representative             Mr.
# 8         8.0   Callahan     Laura  Inside Sales Coordinator             Ms.
# 9         9.0  Dodsworth      Anne      Sales Representative             Ms.
#
#    BirthDate   HireDate                                Address      City  \
# ...

# %%
Employees.isna().sum()
# Out:
# EmployeeID         1
# LastName           0
# FirstName          1
# Title              0
# TitleOfCourtesy    0
# BirthDate          1
# HireDate           1
# Address            1
# City               1
# PostalCode         1
# Country            1
# HomePhone          1
# Extension          1
# Notes              1
# ReportsTo          2
# Full Name          1
# dtype: int64

# %%
Employees['ReportsTo'].fillna(0, inplace=True)

# %%
Employees
# Out:
#    EmployeeID   LastName FirstName                     Title TitleOfCourtesy  \
# 0         1.0          -     Nancy      Sales Representative             Ms.
# 1         NaN          -       NaN      Sales Representative             Ms.
# 2         2.0     Fuller    Andrew     Vice President, Sales             Dr.
# 3         3.0  Leverling     Janet      Sales Representative             Ms.
# 4         4.0    Peacock  Margaret      Sales Representative            Mrs.
# 5         5.0   Buchanan    Steven             Sales Manager             Mr.
# 6         6.0     Suyama   Michael      Sales Representative             Mr.
# 7         7.0       King    Robert      Sales Representative             Mr.
# 8         8.0   Callahan     Laura  Inside Sales Coordinator             Ms.
# 9         9.0  Dodsworth      Anne      Sales Representative             Ms.
#
#    BirthDate   HireDate                                Address      City  \
# ...

# %%
Employees.isna().sum()
# Out:
# EmployeeID         1
# LastName           0
# FirstName          1
# Title              0
# TitleOfCourtesy    0
# BirthDate          1
# HireDate           1
# Address            1
# City               1
# PostalCode         1
# Country            1
# HomePhone          1
# Extension          1
# Notes              1
# ReportsTo          0
# Full Name          1
# dtype: int64

# %%
Employees.dropna(inplace=True)

# %%
Employees
# Out:
#    EmployeeID   LastName FirstName                     Title TitleOfCourtesy  \
# 0         1.0          -     Nancy      Sales Representative             Ms.
# 2         2.0     Fuller    Andrew     Vice President, Sales             Dr.
# 3         3.0  Leverling     Janet      Sales Representative             Ms.
# 4         4.0    Peacock  Margaret      Sales Representative            Mrs.
# 5         5.0   Buchanan    Steven             Sales Manager             Mr.
# 6         6.0     Suyama   Michael      Sales Representative             Mr.
# 7         7.0       King    Robert      Sales Representative             Mr.
# 8         8.0   Callahan     Laura  Inside Sales Coordinator             Ms.
# 9         9.0  Dodsworth      Anne      Sales Representative             Ms.
#
#    BirthDate   HireDate                                Address      City  \
# 0 1968-12-08 1992-05-01     507 - 20th Ave. E._x000D_\nApt. 2A   Seattle
# ...

# %%
OrdersDetails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2155 entries, 0 to 2154
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OrderID    2155 non-null   int64
#  1   ProductID  2155 non-null   int64
#  2   UnitPrice  2155 non-null   float64
#  3   Quantity   2155 non-null   int64
#  4   Discount   2155 non-null   float64
# dtypes: float64(2), int64(3)
# memory usage: 84.3 KB

# %%
OrdersDetails.isna().sum()
# Out:
# OrderID      0
# ProductID    0
# UnitPrice    0
# Quantity     0
# Discount     0
# dtype: int64

# %%
Customers.head()
# Out:
#   CustomerID  Unnamed: 1                         CompanyName     ContactName  \
# 0        NaN         NaN                                 NaN             NaN
# 1        NaN         NaN                                 NaN             NaN
# 2      ALFKI         NaN                 Alfreds Futterkiste    Maria Anders
# 3      ANATR         NaN  Ana Trujillo Emparedados y helados    Ana Trujillo
# 4      ANTON         NaN             Antonio Moreno Taquería  Antonio Moreno
#
#            ContactTitle                        Address         City Region  \
# 0                   NaN                            NaN          NaN    NaN
# 1                   NaN                            NaN          NaN    NaN
# 2  Sales Representative                  Obere Str. 57       Berlin    NaN
# 3                 Owner  Avda. de la Constitución 2222  México D.F.    NaN
# 4                 Owner                Mataderos  2312  México D.F.    NaN
#
#   PostalCode  Country         Phone           Fax
# ...

# %%
Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    91 non-null     object
#  1   Unnamed: 1    0 non-null      float64
#  2   CompanyName   90 non-null     object
#  3   ContactName   91 non-null     object
#  4   ContactTitle  91 non-null     object
#  5   Address       91 non-null     object
#  6   City          91 non-null     object
#  7   Region        31 non-null     object
#  8   PostalCode    90 non-null     object
#  9   Country       91 non-null     object
#  10  Phone         91 non-null     object
#  11  Fax           69 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 8.9+ KB

# %%
Customers.dropna(how='all', inplace=True)

# %%
Customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 91 entries, 2 to 93
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerID    91 non-null     object
#  1   Unnamed: 1    0 non-null      float64
#  2   CompanyName   90 non-null     object
#  3   ContactName   91 non-null     object
#  4   ContactTitle  91 non-null     object
#  5   Address       91 non-null     object
#  6   City          91 non-null     object
#  7   Region        31 non-null     object
#  8   PostalCode    90 non-null     object
#  9   Country       91 non-null     object
#  10  Phone         91 non-null     object
#  11  Fax           69 non-null     object
# dtypes: float64(1), object(11)
# memory usage: 9.2+ KB

# %%
Customers['CompanyName'].fillna('Unknown', inplace=True)

# %%
Customers['PostalCode'].fillna('Unknown', inplace=True)

# %%
Customers.isna().sum()
# Out:
# CustomerID       0
# Unnamed: 1      91
# CompanyName      0
# ContactName      0
# ContactTitle     0
# Address          0
# City             0
# Region          60
# PostalCode       0
# Country          0
# Phone            0
# Fax             22
# dtype: int64

# %%
Products.head()
# Out:
#   ProductID    ProductName  SupplierID  CategoryID      QuantityPerUnit  \
# 0         1           Chai         1.0         1.0   10 boxes x 20 bags
# 1       NaN            NaN         NaN         NaN                  NaN
# 2       NaN            NaN         NaN         NaN                  NaN
# 3         2          Chang         1.0         1.0   24 - 12 oz bottles
# 4       NaN  Aniseed Syrup         1.0         2.0  12 - 550 ml bottles
#
#    UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  Discontinued
# 0       18.0          39.0           0.0          10.0           0.0
# 1        NaN           NaN           NaN           NaN           NaN
# 2        NaN           NaN           NaN           NaN           NaN
# 3       19.0          17.0          40.0          25.0           0.0
# 4       10.0          13.0          70.0          25.0           0.0

# %%
Products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ProductID        85 non-null     object
#  1   ProductName      86 non-null     object
#  2   SupplierID       86 non-null     float64
#  3   CategoryID       86 non-null     float64
#  4   QuantityPerUnit  86 non-null     object
#  5   UnitPrice        86 non-null     float64
#  6   UnitsInStock     86 non-null     float64
#  7   UnitsOnOrder     86 non-null     float64
#  8   ReorderLevel     86 non-null     float64
#  9   Discontinued     86 non-null     float64
# dtypes: float64(7), object(3)
# memory usage: 7.0+ KB

# %%
Products.dropna(how='all',inplace=True)

# %%
Products.isna().sum()
# Out:
# ProductID          1
# ProductName        0
# SupplierID         0
# CategoryID         0
# QuantityPerUnit    0
# UnitPrice          0
# UnitsInStock       0
# UnitsOnOrder       0
# ReorderLevel       0
# Discontinued       0
# dtype: int64

# %%
Products.head()
# Out:
#   ProductID                   ProductName  SupplierID  CategoryID  \
# 0         1                          Chai         1.0         1.0
# 3         2                         Chang         1.0         1.0
# 4       NaN                 Aniseed Syrup         1.0         2.0
# 5         4  Chef Anton's Cajun Seasoning         2.0         2.0
# 6       SSS                             5         2.0         2.0
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0   10 boxes x 20 bags      18.00          39.0           0.0          10.0
# 3   24 - 12 oz bottles      19.00          17.0          40.0          25.0
# 4  12 - 550 ml bottles      10.00          13.0          70.0          25.0
# 5       48 - 6 oz jars      22.00          53.0           0.0           0.0
# 6             36 boxes      21.35           0.0           0.0           0.0
#
#    Discontinued
# 0           0.0
# 3           0.0
# 4           0.0
# 5           0.0
# 6           1.0

# %%
Products['ProductID'].fillna(3, inplace=True)

# %%
Products['ProductName'].replace(5,'SSS', inplace=True)

# %%
Products['ProductID'].replace('SSS', 5, inplace=True)

# %%
Products.head()
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                          Chai         1.0         1.0
# 3          2                         Chang         1.0         1.0
# 4          3                 Aniseed Syrup         1.0         2.0
# 5          4  Chef Anton's Cajun Seasoning         2.0         2.0
# 6          5                           SSS         2.0         2.0
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0   10 boxes x 20 bags      18.00          39.0           0.0          10.0
# 3   24 - 12 oz bottles      19.00          17.0          40.0          25.0
# 4  12 - 550 ml bottles      10.00          13.0          70.0          25.0
# 5       48 - 6 oz jars      22.00          53.0           0.0           0.0
# 6             36 boxes      21.35           0.0           0.0           0.0
#
#    Discontinued
# 0           0.0
# 3           0.0
# 4           0.0
# 5           0.0
# 6           1.0

# %%
Products['SupplierID'] = Products['SupplierID'].astype('int64')
Products['CategoryID'] = Products['CategoryID'].astype('int64')
Products['UnitsInStock'] = Products['UnitsInStock'].astype('int64')
Products['UnitsOnOrder'] = Products['UnitsOnOrder'].astype('int64')
Products['ReorderLevel'] = Products['ReorderLevel'].astype('int64')

# %%
Products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 86 entries, 0 to 87
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ProductID        86 non-null     int64
#  1   ProductName      86 non-null     object
#  2   SupplierID       86 non-null     int64
#  3   CategoryID       86 non-null     int64
#  4   QuantityPerUnit  86 non-null     object
#  5   UnitPrice        86 non-null     float64
#  6   UnitsInStock     86 non-null     int64
#  7   UnitsOnOrder     86 non-null     int64
#  8   ReorderLevel     86 non-null     int64
#  9   Discontinued     86 non-null     float64
# dtypes: float64(2), int64(6), object(2)
# memory usage: 7.4+ KB

# %%
Products.head()
# Out:
#    ProductID                   ProductName  SupplierID  CategoryID  \
# 0          1                          Chai           1           1
# 3          2                         Chang           1           1
# 4          3                 Aniseed Syrup           1           2
# 5          4  Chef Anton's Cajun Seasoning           2           2
# 6          5                           SSS           2           2
#
#        QuantityPerUnit  UnitPrice  UnitsInStock  UnitsOnOrder  ReorderLevel  \
# 0   10 boxes x 20 bags      18.00            39             0            10
# 3   24 - 12 oz bottles      19.00            17            40            25
# 4  12 - 550 ml bottles      10.00            13            70            25
# 5       48 - 6 oz jars      22.00            53             0             0
# 6             36 boxes      21.35             0             0             0
#
#    Discontinued
# 0           0.0
# 3           0.0
# 4           0.0
# 5           0.0
# 6           1.0

# %%
Suppliers.columns
# Out:
# Index(['SupplierID', 'CompanyName', 'ContactName', 'ContactTitle', 'Address',
#        'City', 'Region', 'PostalCode', 'Country', 'Phone', 'Fax', 'HomePage'],
#       dtype='object')

# %%
Suppliers.head()
# Out:
#    SupplierID                         CompanyName                 ContactName  \
# 0           1                      Exotic Liquids            Charlotte Cooper
# 1           2                                 NaN               Shelley Burke
# 2           3           Grandma Kelly's Homestead               Regina Murphy
# 3           4                       Tokyo Traders                Yoshi Nagase
# 4           5  Cooperativa de Quesos 'Las Cabras'  Antonio del Valle Saavedra
#
#            ContactTitle                            Address         City  \
# 0    Purchasing Manager                     49 Gilbert St.       London
# 1   Order Administrator                     P.O. Box 78934  New Orleans
# 2  Sales Representative                     707 Oxford Rd.    Ann Arbor
# 3     Marketing Manager  9-8 Sekimai_x000D_\nMusashino-shi        Tokyo
# 4  Export Administrator                  Calle del Rosal 4       Oviedo
#
# ...

# %%
Suppliers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SupplierID    29 non-null     int64
#  1   CompanyName   28 non-null     object
#  2   ContactName   29 non-null     object
#  3   ContactTitle  29 non-null     object
#  4   Address       29 non-null     object
#  5   City          29 non-null     object
#  6   Region        9 non-null      object
#  7   PostalCode    29 non-null     object
#  8   Country       29 non-null     object
#  9   Phone         29 non-null     object
#  10  Fax           13 non-null     object
#  11  HomePage      3 non-null      object
# dtypes: int64(1), object(11)
# memory usage: 2.8+ KB

# %%
Suppliers.isnull().sum()
# Out:
# SupplierID       0
# CompanyName      1
# ContactName      0
# ContactTitle     0
# Address          0
# City             0
# Region          20
# PostalCode       0
# Country          0
# Phone            0
# Fax             16
# HomePage        26
# dtype: int64

# %%
Suppliers['CompanyName']=Suppliers['CompanyName'].fillna('unknown')

# %%
Suppliers
# Out:
#     SupplierID                             CompanyName  \
# 0            1                          Exotic Liquids
# 1            2                                 unknown
# 2            3               Grandma Kelly's Homestead
# 3            4                           Tokyo Traders
# 4            5      Cooperativa de Quesos 'Las Cabras'
# 5            6                                Mayumi's
# 6            7                           Pavlova, Ltd.
# 7            8                                       3
# 8            9                        PB Knäckebröd AB
# 9           10               Refrescos Americanas LTDA
# 10          11             Heli Süßwaren GmbH & Co. KG
# 11          12       Plutzer Lebensmittelgroßmärkte AG
# 12          13  Nord-Ost-Fisch Handelsgesellschaft mbH
# 13          14                 Formaggi Fortini s.r.l.
# 14          15                         Norske Meierier
# 15          16                       Bigfoot Breweries
# ...

# %%
Suppliers.drop(['Region', 'Fax', 'HomePage','PostalCode','Phone'], axis=1, inplace=True)

# %%
Suppliers
# Out:
#     SupplierID                             CompanyName  \
# 0            1                          Exotic Liquids
# 1            2                                 unknown
# 2            3               Grandma Kelly's Homestead
# 3            4                           Tokyo Traders
# 4            5      Cooperativa de Quesos 'Las Cabras'
# 5            6                                Mayumi's
# 6            7                           Pavlova, Ltd.
# 7            8                                       3
# 8            9                        PB Knäckebröd AB
# 9           10               Refrescos Americanas LTDA
# 10          11             Heli Süßwaren GmbH & Co. KG
# 11          12       Plutzer Lebensmittelgroßmärkte AG
# 12          13  Nord-Ost-Fisch Handelsgesellschaft mbH
# 13          14                 Formaggi Fortini s.r.l.
# 14          15                         Norske Meierier
# 15          16                       Bigfoot Breweries
# ...

# %%
Sales.columns
# Out:
# Index(['OrderID', 'Customer key ', 'EmployeeID', 'OrderDate', 'RequiredDate',
#        'ShippedDate', 'Freight', 'ShipAddress', 'ShipCity', 'ShipRegion',
#        'ShipPostalCode', 'ShipCountry'],
#       dtype='object')

# %%
Sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 837 entries, 0 to 836
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   OrderID         837 non-null    int64
#  1   Customer key    829 non-null    object
#  2   EmployeeID      830 non-null    float64
#  3   OrderDate       830 non-null    datetime64[ns]
#  4   RequiredDate    830 non-null    datetime64[ns]
#  5   ShippedDate     809 non-null    datetime64[ns]
#  6   Freight         830 non-null    float64
#  7   ShipAddress     830 non-null    object
#  8   ShipCity        830 non-null    object
#  9   ShipRegion      323 non-null    object
#  10  ShipPostalCode  811 non-null    object
#  11  ShipCountry     830 non-null    object
# dtypes: datetime64[ns](3), float64(2), int64(1), object(6)
# memory usage: 78.6+ KB

# %%
Sales['ShippedDate']=Sales['ShippedDate'].dt.date

# %%
Sales.isnull().sum()
# Out:
# OrderID             0
# Customer key        8
# EmployeeID          7
# OrderDate           7
# RequiredDate        7
# ShippedDate        28
# Freight             7
# ShipAddress         7
# ShipCity            7
# ShipRegion        514
# ShipPostalCode     26
# ShipCountry         7
# dtype: int64

# %%
Sales.columns = Sales.columns.str.strip()

# %%
Sales = Sales.drop_duplicates(subset=['OrderID'])

# %%
Sales=Sales.dropna(subset=['Customer key'])

# %%
Sales.loc[:, 'ShippedDate'] = Sales['ShippedDate'].ffill()
# Out:
# c:\Users\fg\anaconda3\lib\site-packages\pandas\core\indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
Sales.isnull().sum()
# Out:
# OrderID             0
# Customer key        0
# EmployeeID          0
# OrderDate           0
# RequiredDate        0
# ShippedDate         0
# Freight             0
# ShipAddress         0
# ShipCity            0
# ShipRegion        507
# ShipPostalCode     19
# ShipCountry         0
# dtype: int64

# %%
Sales.drop(['ShipRegion','ShipPostalCode'],axis=1,inplace=True)
# Out:
# c:\Users\fg\anaconda3\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
Sales.isnull().sum()
# Out:
# OrderID         0
# Customer key    0
# EmployeeID      0
# OrderDate       0
# RequiredDate    0
# ShippedDate     0
# Freight         0
# ShipAddress     0
# ShipCity        0
# ShipCountry     0
# dtype: int64

# %%
Suppliers.duplicated(subset=['SupplierID', 'CompanyName', 'ContactName', 'ContactTitle', 'Address',  ])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# dtype: bool

# %%
Sales.to_excel('proje.xlsx',sheet_name='Sales',index=False)

# %%
Suppliers.to_excel('proje.xlsx',sheet_name='Suppliers',index=False)

# %%
output_file = 'cleaned_data.xlsx'
sheets = {'Customers': Customers, 'Employees': Employees, 'OrdersDetails': OrdersDetails, 'Products': Products, 'Categories': categories,'Suppliers': Suppliers, 'Sales': Sales}
with pd.ExcelWriter(output_file, engine='xlsxwriter') as writer:
    for sheet_name, df in sheets.items():
        df.to_excel(writer, sheet_name=sheet_name, index=False)--
